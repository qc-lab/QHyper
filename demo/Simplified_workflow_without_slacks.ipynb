# %% [markdown]
# ### Demo na konferencję EuroHPC (case z QAOA) - draft
# DO ZMIANY: opis
# We will focus on the following workflow instance (for now, in the simplified problem, we will not use the Workflow or WorkflowSchedulingProblem classes, because we want to test the Unbalanced Penalization method https://arxiv.org/pdf/2211.13914.pdf), which is not included in QHyper. But I will leave it here just for reference (especially for observation of what data is in the time and cost matrices).

# %%
import sys
sys.path.append("..")
from QHyper.problems.workflow_scheduling import (
    Workflow,
    WorkflowSchedulingProblem,
)

tasks_file =  "workflows_data/workflows/3_tasks_3_machines_1_path.json"
machines_file = "workflows_data/machines/machines_for_3_tasks_3_machines_1_path.json"
deadline = 13

workflow = Workflow(tasks_file, machines_file, deadline)
wsp = WorkflowSchedulingProblem(workflow)

# %%
wsp.workflow.cost_matrix
# Out:
#        MachineA  MachineB  MachineC
# task1       6.0       8.0       8.0
# task2       3.0       4.0       4.0
# task3      12.0      16.0      16.0

# %%
wsp.workflow.time_matrix
# Out:
#        MachineA  MachineB  MachineC
# task1       6.0       2.0       4.0
# task2       3.0       1.0       2.0
# task3      12.0       4.0       8.0

# %% [markdown]
# Below is the list of the hyperparameters (weights) that can be changed.  I assumed that the weights hyper_b, hyper_c, hyper_d can be the same, since the constraint they represent has a very similar form.

# %%
machine_weight=20
hyper_params = {'cost_function_weight': 1, # weight for: cost function 
                'encoding_machine_1_weight': machine_weight, # weight for: (x[0] + x[1] + x[2] - 1)**2
                'encoding_machine_2_weight': machine_weight, # weight for: (x[3] + x[4] + x[5] - 1)**2
                'encoding_machine_3_weight': machine_weight, # weight for: (x[6] + x[7] + x[8] - 1)**2
                'deadline_linear_form_weight': 1, # weight for: deadline constraint - linear form (-- this is from the unbalanced penalization approach)
                'deadline_quadratic_form_weight': 2} # weight for: deadline constraint - quadratic form

# %% [markdown]
#  DO ZMIANY: generacja tych wzorów z WFCommons

# %%
import numpy as np
import sympy
from sympy.core.expr import Expr

from QHyper.problems.base import Problem
from QHyper.util import Expression


class SimpleWorkflowProblem(Problem):

    
    def __init__(self) -> None:
        num_of_qubits = wsp.workflow.cost_matrix.shape[0] * wsp.workflow.cost_matrix.shape[1]
        self.variables = sympy.symbols(' '.join([f'x{i}' for i in range(num_of_qubits)]))                                  
        self._set_objective_function()
        self._set_constraints()
        
    def _set_objective_function(self) -> None:
        C_f = 6.0*self.variables[0] + 8.0*self.variables[1] + 8.0*self.variables[2] + 3.0*self.variables[3] + 4.0*self.variables[4] + 4.0*self.variables[5] + 12.0*self.variables[6] + 16.0*self.variables[7] + 16.0*self.variables[8]
        

        K_f4_linear = deadline - (6*self.variables[0] + 2*self.variables[1] + 4*self.variables[2] + 3*self.variables[3] +
                            1*self.variables[4] + 2*self.variables[5] + 12*self.variables[6] + 4*self.variables[7] + 8*self.variables[8])
                
        self.objective_function = Expression(hyper_params['cost_function_weight'] * C_f + hyper_params['deadline_linear_form_weight'] *  K_f4_linear)
        
    def _set_constraints(self):
        K_f1 = self.variables[0] + self.variables[1] + self.variables[2] - 1
        K_f2 = self.variables[3] + self.variables[4] + self.variables[5] - 1
        K_f3 = self.variables[6] + self.variables[7] + self.variables[8] - 1

        K_f4_squared = deadline - (6*self.variables[0] + 2*self.variables[1] + 4*self.variables[2] + 3*self.variables[3] +
                            1*self.variables[4] + 2*self.variables[5] + 12*self.variables[6] + 4*self.variables[7] + 8*self.variables[8])

            
        self.constraints = [Expression(K_f1), Expression(K_f2), Expression(K_f3), Expression(K_f4_squared)]
    
    def get_score(self, result, penalty=0):
        
        x = [int(val) for val in result]
    
        if (x[0] + x[1] + x[2] == 1 and 
            x[3] + x[4] + x[5] == 1 and 
            x[6] + x[7] + x[8] == 1 and 
            6*x[0] + 2*x[1] + 4*x[2] + 3*x[3] + 1*x[4] + 2*x[5] + 12*x[6] + 4*x[7] + 8*x[8] <= 13):
            
            return 6.0*x[0] + 8.0*x[1] + 8.0*x[2] + 3.0*x[3] + 4.0*x[4] + 4.0*x[5] + 12.0*x[6] + 16.0*x[7] + 16.0*x[8]
        
        return penalty

# %%
problem = SimpleWorkflowProblem()

# %%
print(f"Variables used to describe objective function"
      f" and constraints: {problem.variables}")
print(f"Objective function: {problem.objective_function}")
print("Constraints (RHS == 0):")
for constraint in problem.constraints:
    print(f"    {constraint}")
# Out:
# Variables used to describe objective function and constraints: (x0, x1, x2, x3, x4, x5, x6, x7, x8)
# Objective function: {('x1',): 6.0, ('x2',): 4.0, ('x4',): 3.0, ('x5',): 2.0, ('x7',): 12.0, ('x8',): 8.0, (): 13}
# Constraints (RHS == 0):
#     {('x0',): 1, ('x1',): 1, ('x2',): 1, (): -1}
#     {('x3',): 1, ('x4',): 1, ('x5',): 1, (): -1}
#     {('x6',): 1, ('x7',): 1, ('x8',): 1, (): -1}
#     {('x0',): -6, ('x1',): -2, ('x2',): -4, ('x3',): -3, ('x4',): -1, ('x5',): -2, ('x6',): -12, ('x7',): -4, ('x8',): -8, (): 13}

# %% [markdown]
# # 3 Using QHyper

# %%
params_config = {
        'angles': [[0.1e-3]*5, [np.pi/2]*5], # QAOA angles - first we have gammas (for the cost Hamiltonian), then we have betas (for the mixer)
        'hyper_args': [1, # do not change - this should be the weight for the 'cost function' but since in our cost function 
                          # we also have the deadline in the linear form (as of now it needs to be implemented this way due to QHyper limitations)
                          # the weight for the actual cost function is set there. THIS WILL NOT WORK WELL WITH HYPER-QAOA.
                          
                       hyper_params['encoding_machine_1_weight'], 
                       hyper_params['encoding_machine_2_weight'], 
                       hyper_params['encoding_machine_3_weight'], 
                       hyper_params['deadline_quadratic_form_weight']],
    }

# %%
# Simple quantum circuit without optimzers will be used to test the results
# WF-QAOA is choosen becasue this PQC has most suitable evaluation function
#DO ZMIANY: nowe API QHyper
from QHyper.solvers.vqa.base import VQA
tester_config = {
    'pqc': {
        'type': 'wfqaoa',
        'layers': 5,
    }
}

tester = VQA(problem, config=tester_config)

# %%
# Create a VQA instance with QAOA as PQC and scipy optimizer
# This can be done in two various way
# 1. Providing dict with config (usefull to save experiment confing in e.g JSON)
# DO ZMIANY sqaoa -> qaoa (backend= "lightning.qubit") oraz QNG optimiser (krok 0.00045) 50 krokow
solver_config = {
    'pqc': {
        'type': 'sqaoa',
        'layers': 5
    }
}
vqa = VQA(problem, config=solver_config)

# %%
# DO ZMIANY vqa.solve()
best_params = vqa.evaluate(params_config)
print(f"Best params: {best_params}")
# Out:
# 0   365.49999999999466   [[1.00003310e-04 9.97073118e-05 9.99692771e-05 1.00701780e-04
#   9.99292196e-05]
#  [2.05105913e+00 1.32267276e-01 1.07511848e+00 8.51303184e-01
#   1.15900589e+00]]
#
# 1   354.107995475204   [[ 4.24158092e-04 -1.90787262e-05  2.71674311e-04  3.60000512e-04
#   -1.05277689e-04]
#  [ 3.84960391e+00 -1.32238331e+00 -7.92836239e-01  4.27235174e-02
#   -1.91565290e-01]]
#
# 2   314.6666071229771   [[ 4.02437794e-04 -5.72576993e-04  5.82813129e-04  6.36238363e-04
#    2.47683747e-04]
#  [ 3.89408790e+00 -1.29535587e+00 -5.17608796e-01 -1.69379346e-01
#   -2.99178423e-01]]
#
# 3   169.18623931659965   [[ 4.10572048e-04 -7.05341368e-04  5.76506196e-04  9.03447627e-04
#    4.79456191e-04]
#  [ 3.73303576e+00 -1.39606139e+00 -5.48367629e-01 -1.98056726e-01
#   -3.41957256e-01]]
#
# 4   135.93687279468824   [[ 3.84609103e-04 -8.93183410e-04  5.10478000e-04  9.66855108e-04
#    5.90830265e-04]
#  [ 3.86477891e+00 -1.34586909e+00 -5.09973826e-01 -1.32640922e-01
#   -2.91909499e-01]]
#
# 5   131.3619198546427   [[ 3.97575251e-04 -8.50160389e-04  4.85110503e-04  1.08658651e-03
#    6.93939857e-04]
#  [ 3.71154510e+00 -1.40062754e+00 -5.40144913e-01 -1.67745206e-01
#   -3.32028273e-01]]
#
# 6   118.84722944920343   [[ 3.97392896e-04 -9.31548197e-04  4.34843156e-04  1.10069409e-03
#    7.41311541e-04]
#  [ 3.78289900e+00 -1.38164922e+00 -5.26606580e-01 -1.36691366e-01
#   -3.07483700e-01]]
#
# 7   116.14908147994943   [[ 4.33017529e-04 -9.22232931e-04  4.15200071e-04  1.14877244e-03
#    7.87845462e-04]
#  [ 3.72849625e+00 -1.40813338e+00 -5.45727469e-01 -1.52239073e-01
#   -3.20666144e-01]]
#
# 8   113.88924565443826   [[ 4.35958618e-04 -9.66474205e-04  3.90776563e-04  1.15396882e-03
#    8.12701492e-04]
#  [ 3.76562063e+00 -1.40028759e+00 -5.39483267e-01 -1.37943260e-01
#   -3.08072525e-01]]
#
# 9   112.88529479295526   [[ 4.58489164e-04 -9.68242847e-04  3.83464596e-04  1.17568877e-03
#    8.37234327e-04]
#  [ 3.75114351e+00 -1.41291900e+00 -5.49488112e-01 -1.45619474e-01
#   -3.12631671e-01]]
#
# 10   112.25946881118432   [[ 4.63918771e-04 -9.92134932e-04  3.74828007e-04  1.17877536e-03
#    8.52325727e-04]
#  [ 3.77034515e+00 -1.41133843e+00 -5.48012142e-01 -1.40800873e-01
#   -3.06698378e-01]]
#
# 11   111.9184377751916   [[ 4.76632759e-04 -9.98808529e-04  3.73552627e-04  1.18779093e-03
#    8.66706750e-04]
#  [ 3.77100761e+00 -1.41725837e+00 -5.52726280e-01 -1.44457173e-01
#   -3.07312462e-01]]
#
# 12   111.69485596893404   [[ 4.82602403e-04 -1.01259880e-03  3.72335057e-04  1.18951634e-03
#    8.77115698e-04]
#  [ 3.78267823e+00 -1.41818995e+00 -5.53241281e-01 -1.43814801e-01
#   -3.04301890e-01]]
#
# 13   111.53246302952037   [[ 4.90636638e-04 -1.02006305e-03  3.73822187e-04  1.19273561e-03
#    8.86765774e-04]
#  [ 3.78837159e+00 -1.42145278e+00 -5.55698909e-01 -1.45996717e-01
#   -3.03463866e-01]]
#
# 14   111.3996331322876   [[ 4.96320050e-04 -1.02922118e-03  3.75563649e-04  1.19322639e-03
#    8.94726518e-04]
#  [ 3.79728281e+00 -1.42313270e+00 -5.56787203e-01 -1.46898944e-01
#   -3.01531930e-01]]
#
# 15   111.28305965017172   [[ 5.02397106e-04 -1.03607621e-03  3.78183173e-04  1.19384243e-03
#    9.02118706e-04]
#  [ 3.80436492e+00 -1.42543103e+00 -5.58378596e-01 -1.48654733e-01
#   -3.00262799e-01]]
#
# 16   111.17639114987858   [[ 5.07653033e-04 -1.04305444e-03  3.80917210e-04  1.19342191e-03
#    9.08760574e-04]
#  [ 3.81223956e+00 -1.42723880e+00 -5.59527279e-01 -1.50068352e-01
#   -2.98707724e-01]]
#
# 17   111.07661637730183   [[ 5.12874596e-04 -1.04910784e-03  3.83859020e-04  1.19285382e-03
#    9.15046110e-04]
#  [ 3.81951010e+00 -1.42916876e+00 -5.60758150e-01 -1.51721352e-01
#   -2.97355933e-01]]
#
# 18   110.98212712356909   [[ 5.17765667e-04 -1.05494618e-03  3.86771609e-04  1.19187570e-03
#    9.20981299e-04]
#  [ 3.82687315e+00 -1.43093114e+00 -5.61823297e-01 -1.53287232e-01
#   -2.95951500e-01]]
#
# 19   110.89203532540681   [[ 5.22543671e-04 -1.06033912e-03  3.89645603e-04  1.19076938e-03
#    9.26713683e-04]
#  [ 3.83396415e+00 -1.43268813e+00 -5.62862593e-01 -1.54912055e-01
#   -2.94621888e-01]]
#
# 20   110.80577773051901   [[ 5.27147186e-04 -1.06550125e-03  3.92405124e-04  1.18950093e-03
#    9.32276415e-04]
#  [ 3.84095795e+00 -1.43436998e+00 -5.63816672e-01 -1.56510108e-01
#   -2.93301752e-01]]
#
# 21   110.72298306770399   [[ 5.31636717e-04 -1.07040296e-03  3.95035053e-04  1.18816757e-03
#    9.37730221e-04]
#  [ 3.84776481e+00 -1.43601878e+00 -5.64722465e-01 -1.58114873e-01
#   -2.92022165e-01]]
#
# 22   110.64337572693675   [[ 5.36003574e-04 -1.07511758e-03  3.97511260e-04  1.18678078e-03
#    9.43100571e-04]
#  [ 3.85442735e+00 -1.43761976e+00 -5.65567989e-01 -1.59704155e-01
#   -2.90766839e-01]]
#
# 23   110.56674220941368   [[ 5.40265497e-04 -1.07965541e-03  3.99826907e-04  1.18537889e-03
#    9.48414711e-04]
#  [ 3.86092577e+00 -1.43918432e+00 -5.66363870e-01 -1.61284651e-01
#   -2.89542475e-01]]
#
# 24   110.49290431451763   [[ 5.44423209e-04 -1.08404704e-03  4.01976089e-04  1.18397589e-03
#    9.53687795e-04]
#  [ 3.86727145e+00 -1.44071042e+00 -5.67109170e-01 -1.62850545e-01
#   -2.88344646e-01]]
#
# 25   110.42170852344643   [[ 5.48482352e-04 -1.08830582e-03  4.03958424e-04  1.18258900e-03
#    9.58932631e-04]
#  [ 3.87346188e+00 -1.44220177e+00 -5.67807933e-01 -1.64402868e-01
#   -2.87174119e-01]]
#
# 26   110.35301768738373   [[ 5.52444234e-04 -1.09244735e-03  4.05775054e-04  1.18122758e-03
#    9.64157233e-04]
#  [ 3.87950170e+00 -1.44365898e+00 -5.68461517e-01 -1.65940094e-01
#   -2.86029141e-01]]
#
# 27   110.28670711195065   [[ 5.56310748e-04 -1.09648170e-03  4.07429102e-04  1.17989990e-03
#    9.69367577e-04]
#  [ 3.88539267e+00 -1.44508378e+00 -5.69072266e-01 -1.67462338e-01
#   -2.84909068e-01]]
#
# 28   110.22266161564586   [[ 5.60082574e-04 -1.10041799e-03  4.08924570e-04  1.17861118e-03
#    9.74567484e-04]
#  [ 3.89113818e+00 -1.44647718e+00 -5.69641875e-01 -1.68969285e-01
#   -2.83812702e-01]]
#
# 29   110.16077385774845   [[ 5.63760291e-04 -1.10426306e-03  4.10266197e-04  1.17736536e-03
#    9.79759529e-04]
#  [ 3.89674109e+00 -1.44784036e+00 -5.70172171e-01 -1.70461046e-01
#   -2.82739073e-01]]
#
# 30   110.10094308463063   [[ 5.67344091e-04 -1.10802268e-03  4.11459092e-04  1.17616492e-03
#    9.84945258e-04]
#  [ 3.90220462e+00 -1.44917431e+00 -5.70664790e-01 -1.71937703e-01
#   -2.81687102e-01]]
#
# 31   110.04307428175957   [[ 5.70834050e-04 -1.11170147e-03  4.12508598e-04  1.17501147e-03
#    9.90125550e-04]
#  [ 3.90753193e+00 -1.45048001e+00 -5.71121336e-01 -1.73399469e-01
#   -2.80655764e-01]]
#
# 32   109.9870775109283   [[ 5.74230108e-04 -1.11530324e-03  4.13420144e-04  1.17390585e-03
#    9.95300797e-04]
#  [ 3.91272623e+00 -1.45175836e+00 -5.71543322e-01 -1.74846579e-01
#   -2.79644030e-01]]
#
# 33   109.93286739973217   [[ 5.77532151e-04 -1.11883115e-03  4.14199168e-04  1.17284838e-03
#    1.00047108e-03]
#  [ 3.91779073e+00 -1.45301024e+00 -5.71932206e-01 -1.76279317e-01
#   -2.78650897e-01]]
#
# 34   109.88036272101617   [[ 5.80740027e-04 -1.12228781e-03  4.14851054e-04  1.17183894e-03
#    1.00563627e-03]
#  [ 3.92272863e+00 -1.45423649e+00 -5.72289382e-01 -1.77697985e-01
#   -2.77675384e-01]]
#
# 35   109.82948604299543   [[ 5.83853574e-04 -1.12567543e-03  4.15381090e-04  1.17087713e-03
#    1.01079613e-03]
#  [ 3.92754311e+00 -1.45543791e+00 -5.72616189e-01 -1.79102903e-01
#   -2.76716539e-01]]
#
# 36   109.78016342964214   [[ 5.86872636e-04 -1.12899589e-03  4.15794445e-04  1.16996229e-03
#    1.01595038e-03]
#  [ 3.93223732e+00 -1.45661529e+00 -5.72913910e-01 -1.80494404e-01
#   -2.75773438e-01]]
#
# 37   109.73232418152891   [[ 5.89797075e-04 -1.13225077e-03  4.16096147e-04  1.16909363e-03
#    1.02109871e-03]
#  [ 3.93681438e+00 -1.45776938e+00 -5.73183779e-01 -1.81872822e-01
#   -2.74845189e-01]]
#
# 38   109.68590060884912   [[ 5.92626779e-04 -1.13544147e-03  4.16291078e-04  1.16827021e-03
#    1.02624086e-03]
#  [ 3.94127737e+00 -1.45890090e+00 -5.73426982e-01 -1.83238498e-01
#   -2.73930930e-01]]
#
# 39   109.64082783130016   [[ 5.95361673e-04 -1.13856917e-03  4.16383961e-04  1.16749102e-03
#    1.03137663e-03]
#  [ 3.94562934e+00 -1.46001056e+00 -5.73644656e-01 -1.84591770e-01
#   -2.73029830e-01]]
#
# 40   109.59704360055285   [[ 5.98001716e-04 -1.14163493e-03  4.16379364e-04  1.16675499e-03
#    1.03650588e-03]
#  [ 3.94987329e+00 -1.46109906e+00 -5.73837898e-01 -1.85932978e-01
#   -2.72141092e-01]]
#
# 41   109.55448814203179   [[ 6.00546915e-04 -1.14463970e-03  4.16281695e-04  1.16606101e-03
#    1.04162854e-03]
#  [ 3.95401217e+00 -1.46216706e+00 -5.74007759e-01 -1.87262456e-01
#   -2.71263949e-01]]
#
# 42   109.51310401329297   [[ 6.02997318e-04 -1.14758432e-03  4.16095206e-04  1.16540796e-03
#    1.04674464e-03]
#  [ 3.95804890e+00 -1.46321520e+00 -5.74155254e-01 -1.88580534e-01
#   -2.70397663e-01]]
#
# 43   109.47283597675384   [[ 6.05353020e-04 -1.15046955e-03  4.15823997e-04  1.16479470e-03
#    1.05185432e-03]
#  [ 3.96198632e+00 -1.46424411e+00 -5.74281356e-01 -1.89887540e-01
#   -2.69541527e-01]]
#
# 44   109.43363088482177   [[ 6.07614165e-04 -1.15329610e-03  4.15472017e-04  1.16422012e-03
#    1.05695780e-03]
#  [ 3.96582726e+00 -1.46525442e+00 -5.74387004e-01 -1.91183793e-01
#   -2.68694863e-01]]
#
# 45   109.39543757577631   [[ 6.09780943e-04 -1.15606463e-03  4.15043069e-04  1.16368309e-03
#    1.06205539e-03]
#  [ 3.96957447e+00 -1.46624671e+00 -5.74473102e-01 -1.92469608e-01
#   -2.67857019e-01]]
#
# 46   109.35820677894088   [[ 6.11853591e-04 -1.15877575e-03  4.14540814e-04  1.16318252e-03
#    1.06714750e-03]
#  [ 3.97323067e+00 -1.46722158e+00 -5.74540519e-01 -1.93745296e-01
#   -2.67027372e-01]]
#
# 47   109.32189102788271   [[ 6.13832395e-04 -1.16143005e-03  4.13968777e-04  1.16271733e-03
#    1.07223465e-03]
#  [ 3.97679850e+00 -1.46817957e+00 -5.74590096e-01 -1.95011156e-01
#   -2.66205324e-01]]
#
# 48   109.28644458054288   [[ 6.15717686e-04 -1.16402809e-03  4.13330351e-04  1.16228647e-03
#    1.07731742e-03]
#  [ 3.98028059e+00 -1.46912125e+00 -5.74622639e-01 -1.96267486e-01
#   -2.65390301e-01]]
#
# 49   109.25182334532789   [[ 6.17509837e-04 -1.16657040e-03  4.12628802e-04  1.16188890e-03
#    1.08239651e-03]
#  [ 3.98367947e+00 -1.47004716e+00 -5.74638929e-01 -1.97514575e-01
#   -2.64581753e-01]]
#
# Best params: {'angles': tensor([[ 6.17509837e-04, -1.16657040e-03,  4.12628802e-04,
#           1.16188890e-03,  1.08239651e-03],
#         [ 3.98367947e+00, -1.47004716e+00, -5.74638929e-01,
#          -1.97514575e-01, -2.64581753e-01]], requires_grad=True), 'hyper_args': tensor([ 1, 20, 20, 20,  2], requires_grad=True)}

# %%
# DO ZMIANY - nowe api do wyników
best_results = tester.evaluate(best_params,print_results=True)
print(f"Best results: {best_results}")
print(f"Params used for optimizer:\n{best_params['angles']},\n"
      f"and params used for hyperoptimizer: {best_params['hyper_args']}")
# Out:
# 100100000, 0.008, 0
# 000010100, 0.007, 0
# 010100010, 0.007, 27.0
# 001010010, 0.007, 28.0
# 001001010, 0.007, 28.0
# 010010001, 0.007, 28.0
# 100001000, 0.007, 0
# 010001010, 0.007, 28.0
# 000001100, 0.007, 0
# 000100001, 0.007, 0
# 000000100, 0.007, 0
# 100010010, 0.007, 26.0
# 000001001, 0.007, 0
# 001100010, 0.007, 27.0
# 010001001, 0.007, 28.0
# 100000010, 0.007, 0
# 000010001, 0.007, 0
# 010000001, 0.007, 0
# 010000100, 0.007, 0
# 001100000, 0.007, 0
# 100110000, 0.007, 0
# 010010010, 0.007, 28.0
# 001101000, 0.007, 0
# 110001000, 0.007, 0
# 100001010, 0.007, 26.0
# 100011000, 0.007, 0
# 110010000, 0.007, 0
# 100101000, 0.007, 0
# 000100100, 0.007, 0
# 001000010, 0.006, 0
# 011100000, 0.006, 0
# 100010000, 0.006, 0
# 001000001, 0.006, 0
# 001110000, 0.006, 0
# 010010100, 0.006, 0
# 101010000, 0.006, 0
# 110100000, 0.006, 0
# 011001000, 0.006, 0
# 000100010, 0.006, 0
# 010011010, 0.006, 0
# 001010001, 0.006, 28.0
# 010100001, 0.006, 27.0
# 010110010, 0.006, 0
# 101000000, 0.006, 0
# 000101010, 0.006, 0
# 010101000, 0.006, 0
# 000011001, 0.006, 0
# 101001000, 0.006, 0
# 000110010, 0.006, 0
# 100100010, 0.006, 25.0
# 001011000, 0.006, 0
# 001001000, 0.006, 0
# 010101010, 0.006, 0
# 011010000, 0.006, 0
# 001011010, 0.006, 0
# 000110001, 0.006, 0
# 110000000, 0.006, 0
# 000000001, 0.006, 0
# 011010010, 0.006, 0
# 011000010, 0.006, 0
# 010001100, 0.006, 0
# 011011000, 0.006, 0
# 000001010, 0.006, 0
# 001001001, 0.006, 0
# 000011010, 0.006, 0
# 011110000, 0.006, 0
# 100000001, 0.006, 0
# 000011100, 0.005, 0
# 101100000, 0.005, 0
# 010000010, 0.005, 0
# 001110010, 0.005, 0
# 010110000, 0.005, 0
# 110011000, 0.005, 0
# 001000100, 0.005, 0
# 000101001, 0.005, 0
# 011101000, 0.005, 0
# 010011001, 0.005, 0
# 011001010, 0.005, 0
# 110000010, 0.005, 0
# 010100000, 0.005, 0
# 110110000, 0.005, 0
# 000000011, 0.005, 0
# 100011010, 0.005, 0
# 100000000, 0.005, 0
# 100010001, 0.005, 0
# 001010000, 0.005, 0
# 110010010, 0.005, 0
# 001101010, 0.005, 0
# 000110100, 0.005, 0
# 000010011, 0.005, 0
# 001100001, 0.005, 0
# 011000000, 0.005, 0
# 001010100, 0.005, 0
# 010100100, 0.005, 0
# 000010010, 0.005, 0
# 010110001, 0.005, 0
# 010011000, 0.005, 0
# 011100010, 0.005, 0
# 010111000, 0.005, 0
# 001111000, 0.005, 0
# 101011000, 0.005, 0
# 110101000, 0.005, 0
# 100110010, 0.004, 0
# 011000001, 0.004, 0
# 000111010, 0.004, 0
# 000001011, 0.004, 0
# 000101000, 0.004, 0
# 110001010, 0.004, 0
# 100111000, 0.004, 0
# 000000110, 0.004, 0
# 100001001, 0.004, 0
# 010001000, 0.004, 0
# 101000010, 0.004, 0
# 000101100, 0.004, 0
# 010000011, 0.004, 0
# 101110000, 0.004, 0
# 001011001, 0.004, 0
# 010101001, 0.004, 0
# 010011100, 0.004, 0
# 111000000, 0.004, 0
# 011011010, 0.004, 0
# 100000100, 0.004, 0
# 001001100, 0.004, 0
# 011010001, 0.004, 0
# 100101010, 0.004, 0
# 000111000, 0.004, 0
# 010111010, 0.004, 0
# 000100011, 0.004, 0
# 111010000, 0.004, 0
# 000010110, 0.004, 0
# 101010010, 0.004, 0
# 110100010, 0.004, 0
# 010010011, 0.004, 0
# 001000000, 0.004, 0
# 101101000, 0.003, 0
# 000110000, 0.003, 0
# 100100001, 0.003, 0
# 011110010, 0.003, 0
# 000000010, 0.003, 0
# 001110001, 0.003, 0
# 011111000, 0.003, 0
# 000111001, 0.003, 0
# 110000001, 0.003, 0
# 010110100, 0.003, 0
# 010010000, 0.003, 0
# 011001001, 0.003, 0
# 111001000, 0.003, 0
# 100010100, 0.003, 0
# 000011011, 0.003, 0
# 001100100, 0.003, 0
# 110011010, 0.003, 0
# 101001010, 0.003, 0
# 011000100, 0.003, 0
# 000001110, 0.003, 0
# 010001011, 0.003, 0
# 001000011, 0.003, 0
# 001111010, 0.003, 0
# 011101010, 0.003, 0
# 100011001, 0.003, 0
# 010000110, 0.003, 0
# 000100000, 0.003, 0
# 110111000, 0.003, 0
# 001101001, 0.003, 0
# 110010001, 0.003, 0
# 111100000, 0.003, 0
# 000011000, 0.003, 0
# 011100001, 0.003, 0
# 000110011, 0.003, 0
# 001011100, 0.002, 0
# 010101100, 0.002, 0
# 110110010, 0.002, 0
# 101100010, 0.002, 0
# 001010011, 0.002, 0
# 011010100, 0.002, 0
# 010100011, 0.002, 0
# 100001100, 0.002, 0
# 000100110, 0.002, 0
# 010111001, 0.002, 0
# 000111100, 0.002, 0
# 111011000, 0.002, 0
# 100110001, 0.002, 0
# 010010110, 0.002, 0
# 011011001, 0.002, 0
# 100111010, 0.002, 0
# 110001001, 0.002, 0
# 101000001, 0.002, 0
# 000101011, 0.002, 0
# 010000000, 0.002, 0
# 000001000, 0.002, 0
# 101011010, 0.002, 0
# 110101010, 0.002, 0
# 010011011, 0.002, 0
# 101111000, 0.002, 0
# 111000010, 0.002, 0
# 000011110, 0.002, 0
# 100000011, 0.002, 0
# 001110100, 0.002, 0
# 111110000, 0.002, 0
# 000000101, 0.002, 0
# 001001011, 0.002, 0
# 110000100, 0.002, 0
# 011001100, 0.002, 0
# 100101001, 0.002, 0
# 100100100, 0.002, 0
# 011110001, 0.002, 0
# 011111010, 0.002, 0
# 110100001, 0.002, 0
# 101010001, 0.002, 0
# 010001110, 0.002, 0
# 001000110, 0.001, 0
# 101110010, 0.001, 0
# 111010010, 0.001, 0
# 010110011, 0.001, 0
# 111101000, 0.001, 0
# 001111001, 0.001, 0
# 100010011, 0.001, 0
# 011000011, 0.001, 0
# 000110110, 0.001, 0
# 100011100, 0.001, 0
# 001100011, 0.001, 0
# 000010000, 0.001, 0
# 001101100, 0.001, 0
# 110011001, 0.001, 0
# 110010100, 0.001, 0
# 011101001, 0.001, 0
# 000010101, 0.001, 0
# 010111100, 0.001, 0
# 011100100, 0.001, 0
# 111001010, 0.001, 0
# 101101010, 0.001, 0
# 101001001, 0.001, 0
# 001011011, 0.001, 0
# 010101011, 0.001, 0
# 010100110, 0.001, 0
# 001010110, 0.001, 0
# 000111011, 0.001, 0
# 011010011, 0.001, 0
# 110111010, 0.001, 0
# 100001011, 0.001, 0
# 011011100, 0.001, 0
# 000101110, 0.001, 0
# 110110001, 0.001, 0
# 100110100, 0.001, 0
# 010011110, 0.001, 0
# 111100010, 0.001, 0
# 110001100, 0.001, 0
# 100111001, 0.001, 0
# 001110011, 0.001, 0
# 101000100, 0.001, 0
# 101100001, 0.001, 0
# 000001101, 0.001, 0
# 110000011, 0.001, 0
# 011001011, 0.001, 0
# 000000000, 0.001, 0
# 111111000, 0.001, 0
# 010000101, 0.001, 0
# 100000110, 0.001, 0
# 111011010, 0.001, 0
# 100100011, 0.001, 0
# 001001110, 0.001, 0
# 111000001, 0.001, 0
# 011110100, 0.001, 0
# 110101001, 0.001, 0
# 101011001, 0.001, 0
# 011111001, 0.001, 0
# 001111100, 0.001, 0
# 100011011, 0.001, 0
# 010110110, 0.001, 0
# 001101011, 0.000, 0
# 101111010, 0.000, 0
# 100101100, 0.000, 0
# 010111011, 0.000, 0
# 110010011, 0.000, 0
# 011000110, 0.000, 0
# 011100011, 0.000, 0
# 111110010, 0.000, 0
# 110100100, 0.000, 0
# 101010100, 0.000, 0
# 111010001, 0.000, 0
# 011011011, 0.000, 0
# 101110001, 0.000, 0
# 000100101, 0.000, 0
# 001100110, 0.000, 0
# 011101100, 0.000, 0
# 100010110, 0.000, 0
# 110011100, 0.000, 0
# 000111110, 0.000, 0
# 010010101, 0.000, 0
# 100110011, 0.000, 0
# 111101010, 0.000, 0
# 110001011, 0.000, 0
# 010101110, 0.000, 0
# 001011110, 0.000, 0
# 000011101, 0.000, 0
# 101000011, 0.000, 0
# 100010111, 0.000, 0
# 011010110, 0.000, 0
# 100000111, 0.000, 0
# 100001111, 0.000, 0
# 111001001, 0.000, 0
# 101010101, 0.000, 0
# 011110011, 0.000, 0
# 110111001, 0.000, 0
# 101001101, 0.000, 0
# 101000101, 0.000, 0
# 110100101, 0.000, 0
# 101101001, 0.000, 0
# 100101101, 0.000, 0
# 100100111, 0.000, 0
# 001100111, 0.000, 0
# 101100101, 0.000, 0
# 001001111, 0.000, 0
# 101001100, 0.000, 0
# 110001101, 0.000, 0
# 110000111, 0.000, 0
# 100110101, 0.000, 0
# 001111011, 0.000, 0
# 100101011, 0.000, 0
# 001010111, 0.000, 0
# 100100101, 0.000, 0
# 110011101, 0.000, 0
# 010100111, 0.000, 0
# 110110100, 0.000, 0
# 110110101, 0.000, 0
# 001011111, 0.000, 0
# 110100011, 0.000, 0
# 100011111, 0.000, 0
# 110010101, 0.000, 0
# 011000111, 0.000, 0
# 110010111, 0.000, 0
# 010110111, 0.000, 0
# 011010111, 0.000, 0
# 111000101, 0.000, 0
# 100001110, 0.000, 0
# 010101111, 0.000, 0
# 101011101, 0.000, 0
# 101010011, 0.000, 0
# 001110111, 0.000, 0
# 000101111, 0.000, 0
# 100011101, 0.000, 0
# 100111100, 0.000, 0
# 110101101, 0.000, 0
# 101000111, 0.000, 0
# 010011111, 0.000, 0
# 011001111, 0.000, 0
# 100111101, 0.000, 0
# 001110110, 0.000, 0
# 111100001, 0.000, 0
# 011101011, 0.000, 0
# 111010101, 0.000, 0
# 001000111, 0.000, 0
# 110011011, 0.000, 0
# 100110111, 0.000, 0
# 101110101, 0.000, 0
# 010001111, 0.000, 0
# 011101101, 0.000, 0
# 001101111, 0.000, 0
# 011110101, 0.000, 0
# 010001101, 0.000, 0
# 011001110, 0.000, 0
# 110001111, 0.000, 0
# 001101101, 0.000, 0
# 011100101, 0.000, 0
# 011100111, 0.000, 0
# 001000101, 0.000, 0
# 000111111, 0.000, 0
# 000110111, 0.000, 0
# 011111100, 0.000, 0
# 111111010, 0.000, 0
# 111011001, 0.000, 0
# 100001101, 0.000, 0
# 001111101, 0.000, 0
# 111001101, 0.000, 0
# 000110101, 0.000, 0
# 110000110, 0.000, 0
# 011011101, 0.000, 0
# 110000101, 0.000, 0
# 101010111, 0.000, 0
# 101101101, 0.000, 0
# 100101111, 0.000, 0
# 010111111, 0.000, 0
# 011011111, 0.000, 0
# 110100111, 0.000, 0
# 111000100, 0.000, 0
# 101001011, 0.000, 0
# 010111110, 0.000, 0
# 101100110, 0.000, 0
# 101101110, 0.000, 0
# 101110110, 0.000, 0
# 011001101, 0.000, 0
# 010010111, 0.000, 0
# 001110101, 0.000, 0
# 011111101, 0.000, 0
# 101100100, 0.000, 0
# 000100111, 0.000, 0
# 111100101, 0.000, 0
# 111001110, 0.000, 0
# 111100110, 0.000, 0
# 110111101, 0.000, 0
# 110110011, 0.000, 0
# 110101100, 0.000, 0
# 011110111, 0.000, 0
# 101111001, 0.000, 0
# 111010110, 0.000, 0
# 101011110, 0.000, 0
# 000011111, 0.000, 0
# 110011111, 0.000, 0
# 110101110, 0.000, 0
# 101011100, 0.000, 0
# 101001111, 0.000, 0
# 100111011, 0.000, 0
# 001101110, 0.000, 0
# 001111111, 0.000, 0
# 100100110, 0.000, 0
# 101001110, 0.000, 0
# 010111101, 0.000, 0
# 111011110, 0.000, 0
# 111110001, 0.000, 0
# 011100110, 0.000, 0
# 111011101, 0.000, 0
# 111000110, 0.000, 0
# 111110110, 0.000, 0
# 111101100, 0.000, 0
# 100011110, 0.000, 0
# 110111110, 0.000, 0
# 110110110, 0.000, 0
# 101111110, 0.000, 0
# 011011110, 0.000, 0
# 011101111, 0.000, 0
# 101100011, 0.000, 0
# 011111011, 0.000, 0
# 110110111, 0.000, 0
# 100010101, 0.000, 0
# 011010101, 0.000, 0
# 110010110, 0.000, 0
# 111000011, 0.000, 0
# 111101110, 0.000, 0
# 110101011, 0.000, 0
# 111111100, 0.000, 0
# 101100111, 0.000, 0
# 111000111, 0.000, 0
# 101011011, 0.000, 0
# 111110100, 0.000, 0
# 010101101, 0.000, 0
# 100111110, 0.000, 0
# 001011101, 0.000, 0
# 101111101, 0.000, 0
# 001100101, 0.000, 0
# 111110101, 0.000, 0
# 101010110, 0.000, 0
# 100111111, 0.000, 0
# 110100110, 0.000, 0
# 111010100, 0.000, 0
# 110011110, 0.000, 0
# 111101001, 0.000, 0
# 010100101, 0.000, 0
# 101111100, 0.000, 0
# 100101110, 0.000, 0
# 011101110, 0.000, 0
# 011110110, 0.000, 0
# 011111110, 0.000, 0
# 010000111, 0.000, 0
# 101011111, 0.000, 0
# 010011101, 0.000, 0
# 101110100, 0.000, 0
# 000001111, 0.000, 0
# 110001110, 0.000, 0
# 111100100, 0.000, 0
# 111010011, 0.000, 0
# 101101100, 0.000, 0
# 100110110, 0.000, 0
# 001010101, 0.000, 0
# 110101111, 0.000, 0
# 111011100, 0.000, 0
# 101110011, 0.000, 0
# 001111110, 0.000, 0
# 000101101, 0.000, 0
# 110111100, 0.000, 0
# 111101101, 0.000, 0
# 111010111, 0.000, 0
# 000000111, 0.000, 0
# 111001100, 0.000, 0
# 101000110, 0.000, 0
# 111111110, 0.000, 0
# 111001011, 0.000, 0
# 101101011, 0.000, 0
# 011111111, 0.000, 0
# 110111011, 0.000, 0
# 010110101, 0.000, 0
# 101110111, 0.000, 0
# 111100011, 0.000, 0
# 111011011, 0.000, 0
# 111111001, 0.000, 0
# 111110011, 0.000, 0
# 011000101, 0.000, 0
# 001001101, 0.000, 0
# 111001111, 0.000, 0
# 101111011, 0.000, 0
# 111101011, 0.000, 0
# 000111101, 0.000, 0
# 101101111, 0.000, 0
# 110111111, 0.000, 0
# 111100111, 0.000, 0
# 111111101, 0.000, 0
# 111111011, 0.000, 0
# 111011111, 0.000, 0
# 000010111, 0.000, 0
# 111110111, 0.000, 0
# 111101111, 0.000, 0
# 100000101, 0.000, 0
# 101111111, 0.000, 0
# 111111111, 0.000, 0
# Best results: 2.401978813322358
# Params used for optimizer:
# [[ 6.17509837e-04 -1.16657040e-03  4.12628802e-04  1.16188890e-03
#    1.08239651e-03]
#  [ 3.98367947e+00 -1.47004716e+00 -5.74638929e-01 -1.97514575e-01
#   -2.64581753e-01]],
# and params used for hyperoptimizer: [ 1 20 20 20  2]
