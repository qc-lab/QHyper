# %%
import rustworkx as rx
from rustworkx.visualization import mpl_draw as draw_graph
import numpy as np

n = 5

graph = rx.PyGraph()
graph.add_nodes_from(np.arange(0, n, 1))
edge_list = [(0, 1, 1.0), (0, 2, 1.0), (0, 4, 1.0), (1, 2, 1.0), (2, 3, 1.0), (3, 4, 1.0)]
graph.add_edges_from(edge_list)
draw_graph(graph, node_size=600, with_labels=True)

# %%
from qiskit.quantum_info import SparsePauliOp
def build_max_cut_paulis(graph: rx.PyGraph) -> list[tuple[str, float]]:
    """Convert the graph to Pauli list.

    This function does the inverse of `build_max_cut_graph`
    """
    pauli_list = []
    for edge in list(graph.edge_list()):
        paulis = ["I"] * len(graph)
        paulis[edge[0]], paulis[edge[1]] = "Z", "Z"

        weight = graph.get_edge_data(edge[0], edge[1])

        pauli_list.append(("".join(paulis)[::-1], weight))

    return pauli_list


max_cut_paulis = build_max_cut_paulis(graph)

cost_hamiltonian = SparsePauliOp.from_list(max_cut_paulis)
print("Cost Function Hamiltonian:", cost_hamiltonian)
# Out:
# Cost Function Hamiltonian: SparsePauliOp(['IIIZZ', 'IIZIZ', 'ZIIIZ', 'IIZZI', 'IZZII', 'ZZIII'],
#               coeffs=[1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j])

# %%
from qiskit.circuit.library import QAOAAnsatz

circuit = QAOAAnsatz(cost_operator=cost_hamiltonian, reps=2)
circuit.measure_all()

circuit.draw('mpl')

# %%
from qiskit_ibm_runtime import QiskitRuntimeService
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager


# QiskitRuntimeService.save_account(channel="ibm_quantum", token="<MY_IBM_QUANTUM_TOKEN>", overwrite=True, set_as_default=True)
service = QiskitRuntimeService(channel='ibm_quantum')
backend = service.least_busy(min_num_qubits=127)
print(backend)

# Create pass manager for transpilation
pm = generate_preset_pass_manager(optimization_level=3,
                                    backend=backend)

candidate_circuit = pm.run(circuit)
candidate_circuit.draw('mpl', fold=False, idle_wires=False)
# Out:
# ---------------------------------------------------------------------------
# AccountNotFoundError                      Traceback (most recent call last)
# Cell In[7], line 6
#       2 from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
#       5 # QiskitRuntimeService.save_account(channel="ibm_quantum", token="<MY_IBM_QUANTUM_TOKEN>", overwrite=True, set_as_default=True)
# ----> 6 service = QiskitRuntimeService(channel='ibm_quantum')
#       7 backend = service.least_busy(min_num_qubits=127)
#       8 print(backend)
#
# File ~/QHyper/venv/lib/python3.12/site-packages/qiskit_ibm_runtime/qiskit_runtime_service.py:144, in QiskitRuntimeService.__init__(self, channel, token, url, filename, name, instance, proxies, verify, channel_strategy, private_endpoint, url_resolver)
#     130 if channel_strategy:
#     131     warnings.warn(
#     132         (
#     133             "As of qiskit-ibm-runtime version 0.30.0, the channel_strategy parameter is "
#    (...)
#     141         stacklevel=2,
#     142     )
# --> 144 self._account = self._discover_account(
#     145     token=token,
#     146     url=url,
#     147     instance=instance,
#     148     channel=channel,
#     149     filename=filename,
#     150     name=name,
#     151     proxies=ProxyConfiguration(**proxies) if proxies else None,
#     152     verify=verify,
#     153     channel_strategy=channel_strategy,
#     154 )
#     156 if private_endpoint is not None:
#     157     self._account.private_endpoint = private_endpoint
#
# File ~/QHyper/venv/lib/python3.12/site-packages/qiskit_ibm_runtime/qiskit_runtime_service.py:258, in QiskitRuntimeService._discover_account(self, token, url, instance, channel, filename, name, proxies, verify, channel_strategy)
#     256         if url:
#     257             logger.warning("Loading default %s account. Input 'url' is ignored.", channel)
# --> 258         account = AccountManager.get(filename=filename, name=name, channel=channel)
#     259 elif any([token, url]):
#     260     # Let's not infer based on these attributes as they may change in the future.
#     261     raise ValueError(
#     262         "'channel' is required if 'token', or 'url' is specified but 'name' is not."
#     263     )
#
# File ~/QHyper/venv/lib/python3.12/site-packages/qiskit_ibm_runtime/accounts/management.py:197, in AccountManager.get(cls, filename, name, channel)
#     194     if account_name in all_config:
#     195         return Account.from_saved_format(all_config[account_name])
# --> 197 raise AccountNotFoundError("Unable to find account.")
#
# AccountNotFoundError: 'Unable to find account.'

# %%
def cost_func_estimator(params, ansatz, hamiltonian, estimator):

    # transform the observable defined on virtual qubits to
    # an observable defined on all physical qubits
    isa_hamiltonian = hamiltonian.apply_layout(ansatz.layout)

    pub = (ansatz, isa_hamiltonian, params)
    job = estimator.run([pub])

    results = job.result()[0]
    cost = results.data.evs

    objective_func_vals.append(cost)


    return cost

# %%
initial_gamma = np.pi
initial_beta = np.pi/2
init_params = [initial_gamma, initial_beta, initial_gamma, initial_beta]

# %%
from qiskit_ibm_runtime import Session, EstimatorV2 as Estimator
from scipy.optimize import minimize

objective_func_vals = [] # Global variable
with Session(backend=backend) as session:
    # If using qiskit-ibm-runtime<0.24.0, change `mode=` to `session=`
    estimator = Estimator(mode=session)
    estimator.options.default_shots = 1000

    # Set simple error suppression/mitigation options
    estimator.options.dynamical_decoupling.enable = True
    estimator.options.dynamical_decoupling.sequence_type = "XY4"
    estimator.options.twirling.enable_gates = True
    estimator.options.twirling.num_randomizations = "auto"

    result = minimize(
        cost_func_estimator,
        init_params,
        args=(candidate_circuit, cost_hamiltonian, estimator),
        method="COBYLA",
        tol=1e-2,
    )
    print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 5
#       2 from scipy.optimize import minimize
#       4 objective_func_vals = [] # Global variable
# ----> 5 with Session(backend=backend) as session:
#       6     # If using qiskit-ibm-runtime<0.24.0, change `mode=` to `session=`
#       7     estimator = Estimator(mode=session)
#       8     estimator.options.default_shots = 1000
#
# NameError: name 'backend' is not defined
