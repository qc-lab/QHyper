# %%
import random
import matplotlib.pyplot as plt

from collections import deque

import pennylane as qml
from pennylane.templates import ApproxTimeEvolution
from pennylane import numpy as np
import itertools

# %%
class TSP:
    def __init__(self, number_of_cities, coords_range=(0, 10000)):
        self.number_of_cities = number_of_cities
        self.coords_range = coords_range
        self.cities_coords = self.get_cities()
        self.distance_matrix = self.calculate_distance_matrix()
        self.normalized_distance_matrix = self.normalize_distance_matrix()
    
    def get_cities(self):
        cities_coords = np.random.randint(self.coords_range[0], self.coords_range[1], size = (self.number_of_cities, 2))
        return cities_coords
           
    def normalize_cities(self):
        max_coords = np.amax(self.cities_coords, axis=0)
        normalized_cities_coords = np.divide(self.cities_coords, max_coords)
        return normalized_cities_coords

    def calculate_distance_between_points(self, point_A, point_B):
        return np.sqrt((point_A[0] - point_B[0])**2 + (point_A[1] - point_B[1])**2)
    
    def calculate_distance_matrix(self):
        distance_matrix = np.zeros((self.number_of_cities, self.number_of_cities))
        for i in range(self.number_of_cities):
            for j in range(i, self.number_of_cities):
                distance_matrix[i][j] = self.calculate_distance_between_points(self.cities_coords[i], self.cities_coords[j])
                distance_matrix[j][i] = distance_matrix[i][j]
        return distance_matrix 
    
    def normalize_distance_matrix(self):
        return np.divide(self.distance_matrix, np.max(self.distance_matrix))

# %%
class QAOA_TSP:
    def __init__(self, tsp_instance, A_1=4, A_2=4, B=1):
        self.tsp_instance = tsp_instance
        self.weights = {'cost_weight': B, 
                        'constraint_each_visited': A_1, 
                        'constraint_each_visited_once': A_2}
        self.cost_operator = self.create_cost_operator()
    
    def calc_bit(self, i, t):
        return i + t * self.tsp_instance.number_of_cities

    def x(self, i, t):
        wire = self.calc_bit(i, t)
        return qml.Hamiltonian([0.5, -0.5], [qml.Identity(wire), qml.PauliZ(wire)])

    def create_cost_operator(self):
        A_1 = self.weights['constraint_each_visited']
        A_2 = self.weights['constraint_each_visited_once']
        B = self.weights['cost_weight']
        
        cost_of_constraint_each_visited = 0    
        for i in range(self.tsp_instance.number_of_cities):
            curr = qml.Identity(0)
            for t in range(self.tsp_instance.number_of_cities):
                curr -= self.x(i, t)    
            for t1 in range(self.tsp_instance.number_of_cities):
                for t2 in range(t1 + 1, self.tsp_instance.number_of_cities):
                    curr += 2 * self.x(i, t1) @ self.x(i, t2)
            cost_of_constraint_each_visited += curr
        cost_of_constraint_each_visited_once = 0
        for t in range(self.tsp_instance.number_of_cities):
            curr = qml.Identity(0)
            for i in range(self.tsp_instance.number_of_cities):
                curr -= self.x(i, t)
            for i1 in range(self.tsp_instance.number_of_cities):
                for i2 in range(i1 + 1, self.tsp_instance.number_of_cities):
                    curr += 2 * self.x(i1, t) @ self.x(i2, t)
            cost_of_constraint_each_visited += curr
        
        cost_of_visiting_cities = 0
        for i, j in itertools.permutations(range(0, self.tsp_instance.number_of_cities), 2):
            curr = qml.Identity(0)
            for t in range(self.tsp_instance.number_of_cities):
                inc_t = t + 1
                if inc_t == self.tsp_instance.number_of_cities:
                    inc_t = 0
                curr += self.x(i, t) @ self.x(j, inc_t)
            cost_of_visiting_cities += float(self.tsp_instance.normalized_distance_matrix[i][j]) * curr 
        
        cost_operator = (
            A_1 * cost_of_constraint_each_visited + 
            A_2 * cost_of_constraint_each_visited_once +
            B * cost_of_visiting_cities
        )
                
        return cost_operator

# %%
def hadamard_layer(wires):
    for i in range(wires):
        qml.Hadamard(i)

# %%
def create_mixing_hamitonian(wires, const=1/2):
    hamiltonian = qml.Identity(0)
    for i in range(wires):
        hamiltonian += qml.Hamiltonian([const], [qml.PauliX(i)])
    # ApproxTimeEvolution(hamiltonian, time, 1)
    return hamiltonian

# %%
n = 3
tsp_instance = TSP(n)
qaoa_tsp = QAOA_TSP(tsp_instance, A_1=4, A_2=4, B=1)

# %%
print(tsp_instance.cities_coords)
# Out:
# [[4548 8172]
#  [4166 3925]
#  [ 613 7322]]

# %%
def qaoa_layer(gamma, beta):
    qml.qaoa.cost_layer(gamma, qaoa_tsp.cost_operator)
    qml.qaoa.mixer_layer(beta, create_mixing_hamitonian(n**2))

# %%
def circuit(params, n_layers=2):
    hadamard_layer(n**2)
    qml.layer(qaoa_layer, n_layers, params[0], params[1])

# %%
dev = qml.device("default.qubit", wires=n**2)


@qml.qnode(dev)
def cost_function(params):
    circuit(params, n_layers=6)
    x = qml.expval(qaoa_tsp.cost_operator)
    return x

# %%
# fig, ax = qml.draw_mpl(circuit, expansion_strategy="device")([[0, 0], [0, 0]], knapsack)
# fig.show()
optimizer = qml.AdamOptimizer()
steps = 70
params = np.array([[0.5, 0.5, 0.5, 0.5, 0.5, 0.5], [0.5, 0.5, 0.5, 0.5, 0.5, 0.5]], requires_grad=True)

# %%
fig, ax = qml.draw_mpl(cost_function, expansion_strategy="device")(params)
fig.show()
# Out:
# /tmp/ipykernel_11901/3773707193.py:2: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
for i in range(steps):
    params = optimizer.step(cost_function, params)
    if i % 5 == 0:
        print(params)

print("Optimal Parameters")
print(params)
# Out:
# [[0.49 0.49 0.49 0.49 0.51 0.51]
#  [0.51 0.51 0.49 0.51 0.49 0.51]]
# [[0.4914246  0.45438651 0.46338629 0.48282096 0.51040549 0.55903432]
#  [0.55943501 0.55546063 0.45063888 0.52296166 0.45500286 0.5268931 ]]
# [[0.52494517 0.44685209 0.44589047 0.47995136 0.51770415 0.59740755]
#  [0.60384152 0.59997311 0.44547063 0.55946159 0.41790274 0.53761928]]
# [[0.55341174 0.43387356 0.43976495 0.47013451 0.52033578 0.61186107]
#  [0.62449168 0.59566321 0.43934018 0.60283148 0.40489266 0.53324282]]
# [[0.56975789 0.40467403 0.4492421  0.46461207 0.51704552 0.60588622]
#  [0.63433339 0.55906191 0.4075104  0.6420255  0.40923006 0.51025641]]
# [[0.58653211 0.38681639 0.46540099 0.46536748 0.51614173 0.60659493]
#  [0.64201598 0.52163455 0.38140811 0.68965776 0.4377643  0.46613138]]
# [[0.59698188 0.38314603 0.46273602 0.45983856 0.52848274 0.61806694]
#  [0.66305887 0.49437218 0.35465415 0.74108014 0.47731436 0.41488481]]
    print(f"Key: {get_bin(key, n**2)} with probability {val}   | correct: {'True' if get_bin(key, n**2) in correct_results_3 else 'False'}")
# Out:
# Key: 100010001 with probability 0.09316905676336623   | correct: True
# Key: 010001100 with probability 0.09316905676336618   | correct: True
# Key: 100001010 with probability 0.09316905676336618   | correct: True
# Key: 001100010 with probability 0.0931690567633661   | correct: True
# Key: 001010100 with probability 0.09316905676336606   | correct: True
# Key: 010100001 with probability 0.09316905676336593   | correct: True
# Key: 101010010 with probability 0.016092880953769765   | correct: False
# Key: 010101010 with probability 0.016092880953769755   | correct: False
# Key: 010010101 with probability 0.016092880953769737   | correct: False
# Key: 110001001 with probability 0.011428086590622017   | correct: False
# Key: 001001110 with probability 0.011428086590622014   | correct: False
# Key: 001110001 with probability 0.011428086590622   | correct: False
# Key: 000000000 with probability 0.009541949886699654   | correct: False
# Key: 010001010 with probability 0.006295083184115631   | correct: False
# Key: 001010010 with probability 0.006295083184115624   | correct: False
# Key: 010010001 with probability 0.006295083184115622   | correct: False
# Key: 010001001 with probability 0.005035305773146769   | correct: False
# Key: 001001010 with probability 0.005035305773146752   | correct: False
# Key: 001010001 with probability 0.005035305773146744   | correct: False
# Key: 011100100 with probability 0.004946182167934683   | correct: False
# Key: 100100011 with probability 0.004946182167934675   | correct: False
# Key: 100011100 with probability 0.004946182167934672   | correct: False
# Key: 100011011 with probability 0.004276208720226487   | correct: False
# Key: 011100011 with probability 0.004276208720226486   | correct: False
# Key: 011011100 with probability 0.004276208720226476   | correct: False
# Key: 010010010 with probability 0.003508154096523163   | correct: False
# Key: 001001001 with probability 0.0030210684126352884   | correct: False
# Key: 111000000 with probability 0.0029921685222319126   | correct: False
# Key: 000111000 with probability 0.002992168522231907   | correct: False
# Key: 000000111 with probability 0.002992168522231905   | correct: False
# Key: 110001110 with probability 0.0029713302109849954   | correct: False
# Key: 110110001 with probability 0.002971330210984992   | correct: False
# Key: 001110110 with probability 0.0029713302109849894   | correct: False
# Key: 010100010 with probability 0.002962014100786567   | correct: False
# Key: 100010010 with probability 0.0029620141007865655   | correct: False
# Key: 010010100 with probability 0.002962014100786555   | correct: False
# Key: 010101101 with probability 0.002843982101197196   | correct: False
# Key: 101010101 with probability 0.002843982101197195   | correct: False
# Key: 101101010 with probability 0.0028439821011971905   | correct: False
# Key: 000010101 with probability 0.00256126763667217   | correct: False
# Key: 010000101 with probability 0.002561267636672168   | correct: False
# Key: 101000010 with probability 0.0025612676366721667   | correct: False
# Key: 010101000 with probability 0.002561267636672166   | correct: False
# Key: 101010000 with probability 0.0025612676366721645   | correct: False
# Key: 000101010 with probability 0.002561267636672164   | correct: False
# Key: 100100100 with probability 0.0024464014107413523   | correct: False
# Key: 010101001 with probability 0.0022169102902131815   | correct: False
# Key: 101001010 with probability 0.0022169102902131737   | correct: False
# Key: 010001101 with probability 0.002216910290213171   | correct: False
# Key: 101010001 with probability 0.002216910290213171   | correct: False
# Key: 001101010 with probability 0.002216910290213169   | correct: False
# Key: 001010101 with probability 0.002216910290213167   | correct: False
# Key: 100000011 with probability 0.00198194067818285   | correct: False
# Key: 000011100 with probability 0.0019819406781828443   | correct: False
# Key: 000100011 with probability 0.001981940678182844   | correct: False
# Key: 011000100 with probability 0.001981940678182843   | correct: False
# Key: 011100000 with probability 0.0019819406781828425   | correct: False
# Key: 100011000 with probability 0.001981940678182842   | correct: False
# Key: 000001110 with probability 0.001973583517710718   | correct: False
# Key: 000110001 with probability 0.0019735835177107116   | correct: False
# Key: 001000110 with probability 0.0019735835177107116   | correct: False
# Key: 110001000 with probability 0.0019735835177107095   | correct: False
# Key: 110000001 with probability 0.001973583517710709   | correct: False
# Key: 001110000 with probability 0.0019735835177107077   | correct: False
# Key: 001110010 with probability 0.0018900187384169901   | correct: False
# Key: 001010110 with probability 0.0018900187384169893   | correct: False
# Key: 010001110 with probability 0.0018900187384169888   | correct: False
# Key: 110010001 with probability 0.0018900187384169867   | correct: False
# Key: 010110001 with probability 0.0018900187384169806   | correct: False
# Key: 110001010 with probability 0.0018900187384169776   | correct: False
# Key: 001010000 with probability 0.0018388016085612538   | correct: False
# Key: 001000010 with probability 0.0018388016085612536   | correct: False
# Key: 010001000 with probability 0.0018388016085612517   | correct: False
# Key: 000010001 with probability 0.0018388016085612512   | correct: False
# Key: 000001010 with probability 0.001838801608561246   | correct: False
# Key: 010000001 with probability 0.0018388016085612417   | correct: False
# Key: 100001001 with probability 0.0017895537206393374   | correct: False
# Key: 001100001 with probability 0.001789553720639333   | correct: False
# Key: 001001100 with probability 0.0017895537206393277   | correct: False
# Key: 101100010 with probability 0.0015103880487342318   | correct: False
# Key: 010100101 with probability 0.0015103880487342294   | correct: False
# Key: 010101100 with probability 0.0015103880487342281   | correct: False
# Key: 101010100 with probability 0.001510388048734226   | correct: False
# Key: 100010101 with probability 0.0015103880487342255   | correct: False
# Key: 100101010 with probability 0.0015103880487342181   | correct: False
# Key: 100010000 with probability 0.0013178634500273026   | correct: False
# Key: 000100010 with probability 0.0013178634500272952   | correct: False
# Key: 010000100 with probability 0.0013178634500272926   | correct: False
# Key: 100000010 with probability 0.0013178634500272887   | correct: False
# Key: 000010100 with probability 0.0013178634500272883   | correct: False
# Key: 010100000 with probability 0.0013178634500272826   | correct: False
# Key: 000000100 with probability 0.001283847333100773   | correct: False
# Key: 000100000 with probability 0.001283847333100766   | correct: False
# Key: 100000000 with probability 0.0012838473331007656   | correct: False
# Key: 100110001 with probability 0.001237424164524721   | correct: False
# Key: 100001110 with probability 0.0012374241645247196   | correct: False
# Key: 001110100 with probability 0.0012374241645247155   | correct: False
# Key: 110001100 with probability 0.001237424164524712   | correct: False
# Key: 110100001 with probability 0.0012374241645247098   | correct: False
# Key: 001100110 with probability 0.0012374241645247094   | correct: False
# Key: 111111111 with probability 0.0012119665730299823   | correct: False
# Key: 000001100 with probability 0.00120384926312412   | correct: False
# Key: 100000001 with probability 0.00120384926312412   | correct: False
# Key: 100001000 with probability 0.0012038492631241198   | correct: False
# Key: 000100001 with probability 0.0012038492631241168   | correct: False
# Key: 001100000 with probability 0.0012038492631241155   | correct: False
# Key: 001000100 with probability 0.0012038492631241146   | correct: False
# Key: 110100110 with probability 0.0009713447386611048   | correct: False
# Key: 110110100 with probability 0.0009713447386611041   | correct: False
# Key: 100110110 with probability 0.0009713447386611014   | correct: False
# Key: 000001000 with probability 0.0009631649289193156   | correct: False
# Key: 000000001 with probability 0.0009631649289193084   | correct: False
# Key: 001000000 with probability 0.0009631649289193081   | correct: False
# Key: 010000000 with probability 0.0008884599035952273   | correct: False
# Key: 000010000 with probability 0.0008884599035952243   | correct: False
# Key: 000000010 with probability 0.0008884599035952222   | correct: False
# Key: 010111010 with probability 0.0008690822912064884   | correct: False
# Key: 111010010 with probability 0.0008690822912064875   | correct: False
# Key: 010010111 with probability 0.0008690822912064837   | correct: False
# Key: 101100101 with probability 0.0008528409354387077   | correct: False
# Key: 101101100 with probability 0.0008528409354387074   | correct: False
# Key: 100101101 with probability 0.0008528409354387071   | correct: False
# Key: 100011101 with probability 0.0008482613251934629   | correct: False
# Key: 011100101 with probability 0.0008482613251934617   | correct: False
# Key: 100101011 with probability 0.0008482613251934596   | correct: False
# Key: 101011100 with probability 0.0008482613251934584   | correct: False
# Key: 101100011 with probability 0.000848261325193456   | correct: False
# Key: 011101100 with probability 0.0008482613251934541   | correct: False
# Key: 100011110 with probability 0.0007796465661482814   | correct: False
# Key: 011110100 with probability 0.0007796465661482801   | correct: False
# Key: 110100011 with probability 0.0007796465661482786   | correct: False
# Key: 100110011 with probability 0.0007796465661482774   | correct: False
# Key: 110011100 with probability 0.0007796465661482765   | correct: False
# Key: 011100110 with probability 0.0007796465661482758   | correct: False
# Key: 011011011 with probability 0.0007634175309478197   | correct: False
# Key: 111000101 with probability 0.0007461774549152473   | correct: False
# Key: 000101111 with probability 0.0007461774549152447   | correct: False
# Key: 101000111 with probability 0.0007461774549152447   | correct: False
# Key: 000111101 with probability 0.0007461774549152442   | correct: False
# Key: 111101000 with probability 0.0007461774549152434   | correct: False
# Key: 101111000 with probability 0.0007461774549152425   | correct: False
# Key: 110011001 with probability 0.0007321507805237465   | correct: False
# Key: 011110001 with probability 0.0007321507805237394   | correct: False
# Key: 110001011 with probability 0.0007321507805237394   | correct: False
# Key: 001011110 with probability 0.0007321507805237387   | correct: False
# Key: 011001110 with probability 0.0007321507805237381   | correct: False
# Key: 001110011 with probability 0.0007321507805237357   | correct: False
# Key: 000011011 with probability 0.0007160256043740334   | correct: False
# Key: 011000011 with probability 0.0007160256043740325   | correct: False
# Key: 011011000 with probability 0.0007160256043740325   | correct: False
# Key: 100010100 with probability 0.0007085407068493345   | correct: False
# Key: 100100010 with probability 0.0007085407068493336   | correct: False
# Key: 010100100 with probability 0.0007085407068493316   | correct: False
# Key: 010011101 with probability 0.0006708969067539268   | correct: False
# Key: 011010101 with probability 0.0006708969067539263   | correct: False
# Key: 010101011 with probability 0.0006708969067539244   | correct: False
# Key: 011101010 with probability 0.0006708969067539212   | correct: False
# Key: 101011010 with probability 0.0006708969067539211   | correct: False
# Key: 101010011 with probability 0.0006708969067539186   | correct: False
# Key: 001111001 with probability 0.0006665766484537251   | correct: False
# Key: 111001001 with probability 0.0006665766484537246   | correct: False
# Key: 001001111 with probability 0.0006665766484537233   | correct: False
# Key: 000111110 with probability 0.0006334485241184519   | correct: False
# Key: 110000111 with probability 0.0006334485241184494   | correct: False
# Key: 110111000 with probability 0.0006334485241184494   | correct: False
# Key: 111000110 with probability 0.0006334485241184484   | correct: False
# Key: 000110111 with probability 0.0006334485241184476   | correct: False
# Key: 111110000 with probability 0.0006334485241184467   | correct: False
# Key: 110100101 with probability 0.000598437930157495   | correct: False
# Key: 101100110 with probability 0.0005984379301574949   | correct: False
# Key: 100110101 with probability 0.0005984379301574945   | correct: False
# Key: 110101100 with probability 0.0005984379301574935   | correct: False
# Key: 100101110 with probability 0.0005984379301574931   | correct: False
# Key: 101110100 with probability 0.0005984379301574916   | correct: False
# Key: 000110110 with probability 0.0005940360046163529   | correct: False
# Key: 110110000 with probability 0.0005940360046163512   | correct: False
# Key: 110000110 with probability 0.000594036004616351   | correct: False
# Key: 100010011 with probability 0.0005462035230534108   | correct: False
# Key: 011010100 with probability 0.0005462035230534103   | correct: False
# Key: 100011010 with probability 0.0005462035230534088   | correct: False
# Key: 010100011 with probability 0.0005462035230534074   | correct: False
# Key: 010011100 with probability 0.0005462035230534056   | correct: False
# Key: 011100010 with probability 0.0005462035230534008   | correct: False
# Key: 110101011 with probability 0.0005303653138256963   | correct: False
# Key: 011101110 with probability 0.0005303653138256945   | correct: False
# Key: 110011101 with probability 0.0005303653138256944   | correct: False
# Key: 101110011 with probability 0.0005303653138256932   | correct: False
# Key: 101011110 with probability 0.000530365313825692   | correct: False
# Key: 011110101 with probability 0.0005303653138256894   | correct: False
# Key: 001100100 with probability 0.0005211569876687005   | correct: False
# Key: 100100001 with probability 0.0005211569876686982   | correct: False
# Key: 100001100 with probability 0.0005211569876686976   | correct: False
# Key: 010000111 with probability 0.0005152145264034847   | correct: False
# Key: 111000010 with probability 0.0005152145264034846   | correct: False
# Key: 000010111 with probability 0.000515214526403484   | correct: False
# Key: 000111010 with probability 0.000515214526403484   | correct: False
# Key: 111010000 with probability 0.0005152145264034834   | correct: False
# Key: 010111000 with probability 0.0005152145264034825   | correct: False
# Key: 011001100 with probability 0.0004992723674111408   | correct: False
# Key: 100001011 with probability 0.0004992723674111408   | correct: False
# Key: 011100001 with probability 0.0004992723674111407   | correct: False
# Key: 001011100 with probability 0.000499272367411139   | correct: False
# Key: 100011001 with probability 0.0004992723674111361   | correct: False
# Key: 001100011 with probability 0.0004992723674111349   | correct: False
# Key: 011110000 with probability 0.0004978582524914081   | correct: False
# Key: 000011110 with probability 0.0004978582524914069   | correct: False
# Key: 110011000 with probability 0.0004978582524914067   | correct: False
# Key: 011000110 with probability 0.000497858252491406   | correct: False
# Key: 110000011 with probability 0.0004978582524914039   | correct: False
# Key: 000110011 with probability 0.0004978582524914019   | correct: False
# Key: 000101101 with probability 0.000494128662599729   | correct: False
# Key: 101000101 with probability 0.0004941286625997289   | correct: False
# Key: 101101000 with probability 0.0004941286625997252   | correct: False
# Key: 101000100 with probability 0.0004851994222472313   | correct: False
# Key: 100000101 with probability 0.0004851994222472304   | correct: False
# Key: 000100101 with probability 0.0004851994222472287   | correct: False
# Key: 000101100 with probability 0.0004851994222472277   | correct: False
# Key: 101100000 with probability 0.00048519942224722716   | correct: False
# Key: 100101000 with probability 0.00048519942224722705   | correct: False
# Key: 001101110 with probability 0.00048238782135664505   | correct: False
# Key: 110001101 with probability 0.0004823878213566429   | correct: False
# Key: 001110101 with probability 0.00048238782135664267   | correct: False
# Key: 101001110 with probability 0.0004823878213566418   | correct: False
# Key: 110101001 with probability 0.00048238782135664153   | correct: False
# Key: 101110001 with probability 0.00048238782135663475   | correct: False
# Key: 011011001 with probability 0.0004724741727679362   | correct: False
# Key: 011001011 with probability 0.00047247417276793545   | correct: False
# Key: 001011011 with probability 0.00047247417276793534   | correct: False
# Key: 000101001 with probability 0.0004538088915589096   | correct: False
# Key: 000001101 with probability 0.0004538088915589094   | correct: False
# Key: 101000001 with probability 0.00045380889155890915   | correct: False
# Key: 001000101 with probability 0.0004538088915589073   | correct: False
# Key: 101001000 with probability 0.0004538088915589068   | correct: False
# Key: 001101000 with probability 0.000453808891558906   | correct: False
# Key: 100000110 with probability 0.00041879461523439365   | correct: False
# Key: 000110100 with probability 0.00041879461523439056   | correct: False
# Key: 100110000 with probability 0.0004187946152343905   | correct: False
# Key: 110000100 with probability 0.0004187946152343903   | correct: False
# Key: 000100110 with probability 0.0004187946152343896   | correct: False
# Key: 110100000 with probability 0.0004187946152343896   | correct: False
# Key: 010101110 with probability 0.00039889505929325544   | correct: False
# Key: 101110010 with probability 0.0003988950592932536   | correct: False
# Key: 010110101 with probability 0.00039889505929325295   | correct: False
# Key: 110101010 with probability 0.0003988950592932525   | correct: False
# Key: 101010110 with probability 0.00039889505929325213   | correct: False
# Key: 110010101 with probability 0.00039889505929325186   | correct: False
# Key: 000101011 with probability 0.0003907339659906831   | correct: False
# Key: 101011000 with probability 0.0003907339659906814   | correct: False
# Key: 000011101 with probability 0.0003907339659906798   | correct: False
# Key: 101000011 with probability 0.0003907339659906798   | correct: False
# Key: 011000101 with probability 0.00039073396599067866   | correct: False
# Key: 011101000 with probability 0.00039073396599067844   | correct: False
# Key: 011000000 with probability 0.0003765976521742082   | correct: False
# Key: 000000011 with probability 0.0003765976521742079   | correct: False
# Key: 000011000 with probability 0.00037659765217420716   | correct: False
# Key: 111000111 with probability 0.0003603356459188641   | correct: False
# Key: 000111111 with probability 0.0003603356459188636   | correct: False
# Key: 111111000 with probability 0.0003603356459188629   | correct: False
# Key: 010110000 with probability 0.0003523148088912984   | correct: False
# Key: 000110010 with probability 0.00035231480889129737   | correct: False
# Key: 110010000 with probability 0.00035231480889129656   | correct: False
# Key: 000010110 with probability 0.00035231480889129634   | correct: False
# Key: 110000010 with probability 0.00035231480889129504   | correct: False
# Key: 010000110 with probability 0.00035231480889129493   | correct: False
# Key: 101101001 with probability 0.0003508693798245369   | correct: False
# Key: 101001101 with probability 0.0003508693798245357   | correct: False
# Key: 001101101 with probability 0.0003508693798245348   | correct: False
# Key: 000111011 with probability 0.0003123837062527569   | correct: False
# Key: 011000111 with probability 0.00031238370625275626   | correct: False
# Key: 111011000 with probability 0.0003123837062527561   | correct: False
# Key: 011111000 with probability 0.00031238370625275556   | correct: False
# Key: 000011111 with probability 0.0003123837062527554   | correct: False
# Key: 111000011 with probability 0.0003123837062527549   | correct: False
# Key: 001011010 with probability 0.00031068084278451614   | correct: False
# Key: 010001011 with probability 0.0003106808427845153   | correct: False
# Key: 011001010 with probability 0.0003106808427845133   | correct: False
# Key: 001010011 with probability 0.0003106808427845132   | correct: False
# Key: 010011001 with probability 0.000310680842784513   | correct: False
# Key: 011010001 with probability 0.0003106808427845123   | correct: False
# Key: 010010000 with probability 0.00030077773066316605   | correct: False
# Key: 010000010 with probability 0.0003007777306631641   | correct: False
# Key: 000010010 with probability 0.00030077773066316296   | correct: False
# Key: 010011011 with probability 0.0002839240271343058   | correct: False
# Key: 011011010 with probability 0.0002839240271343033   | correct: False
# Key: 011010011 with probability 0.00028392402713430323   | correct: False
# Key: 001000111 with probability 0.00028006157985423235   | correct: False
# Key: 001111000 with probability 0.00028006157985423176   | correct: False
# Key: 111001000 with probability 0.0002800615798542312   | correct: False
# Key: 000111001 with probability 0.00028006157985423083   | correct: False
# Key: 000001111 with probability 0.00028006157985423056   | correct: False
# Key: 111000001 with probability 0.0002800615798542296   | correct: False
# Key: 011000001 with probability 0.00026544328695237167   | correct: False
# Key: 000001011 with probability 0.0002654432869523707   | correct: False
# Key: 011001000 with probability 0.00026544328695237004   | correct: False
# Key: 000011001 with probability 0.00026544328695236934   | correct: False
# Key: 001011000 with probability 0.0002654432869523693   | correct: False
# Key: 001000011 with probability 0.00026544328695236836   | correct: False
# Key: 010110110 with probability 0.0002556385994617765   | correct: False
# Key: 110110010 with probability 0.00025563859946177545   | correct: False
# Key: 110010110 with probability 0.0002556385994617754   | correct: False
# Key: 110110110 with probability 0.0002490669032109745   | correct: False
# Key: 110010010 with probability 0.00023891269326116238   | correct: False
# Key: 010110010 with probability 0.00023891269326116143   | correct: False
# Key: 010010110 with probability 0.00023891269326116086   | correct: False
# Key: 001000001 with probability 0.0002384631764603733   | correct: False
# Key: 000001001 with probability 0.00023846317646037207   | correct: False
# Key: 001001000 with probability 0.00023846317646037082   | correct: False
# Key: 010000011 with probability 0.0002334315228484742   | correct: False
# Key: 000011010 with probability 0.00023343152284847394   | correct: False
# Key: 010011000 with probability 0.0002334315228484739   | correct: False
# Key: 011000010 with probability 0.000233431522848473   | correct: False
# Key: 000010011 with probability 0.00023343152284847283   | correct: False
# Key: 011010000 with probability 0.0002334315228484724   | correct: False
# Key: 011110110 with probability 0.00022589893251408492   | correct: False
# Key: 110110011 with probability 0.000225898932514084   | correct: False
# Key: 110011110 with probability 0.0002258989325140825   | correct: False
# Key: 110100010 with probability 0.00022142809184930414   | correct: False
# Key: 010110100 with probability 0.00022142809184930377   | correct: False
# Key: 100110010 with probability 0.00022142809184930363   | correct: False
# Key: 100010110 with probability 0.00022142809184930306   | correct: False
# Key: 110010100 with probability 0.00022142809184930233   | correct: False
# Key: 010100110 with probability 0.0002214280918493017   | correct: False
# Key: 001001101 with probability 0.0002170149179664257   | correct: False
# Key: 001101001 with probability 0.00021701491796642522   | correct: False
# Key: 101001001 with probability 0.00021701491796642438   | correct: False
# Key: 001001011 with probability 0.00021546100774198957   | correct: False
# Key: 011001001 with probability 0.0002154610077419891   | correct: False
# Key: 001011001 with probability 0.00021546100774198757   | correct: False
# Key: 011101101 with probability 0.00021397427707064114   | correct: False
# Key: 101101011 with probability 0.00021397427707064005   | correct: False
# Key: 101011101 with probability 0.00021397427707063753   | correct: False
# Key: 111110011 with probability 0.000211571621309574   | correct: False
# Key: 110111011 with probability 0.0002115716213095737   | correct: False
# Key: 110011111 with probability 0.0002115716213095736   | correct: False
# Key: 011111110 with probability 0.00021157162130957356   | correct: False
# Key: 011110111 with probability 0.0002115716213095734   | correct: False
# Key: 111011110 with probability 0.0002115716213095732   | correct: False
# Key: 000110000 with probability 0.00020527666861787933   | correct: False
# Key: 000000110 with probability 0.00020527666861787833   | correct: False
# Key: 110000000 with probability 0.00020527666861787792   | correct: False
# Key: 100101001 with probability 0.00018580605584120612   | correct: False
# Key: 100001101 with probability 0.00018580605584120476   | correct: False
# Key: 001100101 with probability 0.0001858060558412045   | correct: False
# Key: 101001100 with probability 0.0001858060558412041   | correct: False
# Key: 001101100 with probability 0.0001858060558412032   | correct: False
# Key: 101100001 with probability 0.00018580605584120116   | correct: False
# Key: 010010011 with probability 0.00018334038780393877   | correct: False
# Key: 010011010 with probability 0.0001833403878039383   | correct: False
# Key: 011010010 with probability 0.00018334038780393685   | correct: False
# Key: 110100100 with probability 0.00017336919392165904   | correct: False
# Key: 100100110 with probability 0.0001733691939216565   | correct: False
# Key: 100110100 with probability 0.00017336919392165614   | correct: False
# Key: 111100100 with probability 0.0001674235017676368   | correct: False
# Key: 100111100 with probability 0.00016742350176763676   | correct: False
# Key: 100100111 with probability 0.00016742350176763608   | correct: False
# Key: 000100100 with probability 0.0001638599205890089   | correct: False
# Key: 100100000 with probability 0.00016385992058900754   | correct: False
# Key: 100000100 with probability 0.00016385992058900732   | correct: False
# Key: 101101101 with probability 0.00015520108137986505   | correct: False
# Key: 000110101 with probability 0.00014763965975935032   | correct: False
# Key: 101000110 with probability 0.00014763965975934983   | correct: False
# Key: 110000101 with probability 0.00014763965975934964   | correct: False
# Key: 110101000 with probability 0.00014763965975934901   | correct: False
# Key: 000101110 with probability 0.000147639659759348   | correct: False
# Key: 101110000 with probability 0.00014763965975934793   | correct: False
# Key: 011111011 with probability 0.00013853405263103476   | correct: False
# Key: 011011111 with probability 0.00013853405263103386   | correct: False
# Key: 111011011 with probability 0.0001385340526310335   | correct: False
# Key: 101100100 with probability 0.00012634638793702717   | correct: False
# Key: 100101100 with probability 0.00012634638793702674   | correct: False
# Key: 100100101 with probability 0.00012634638793702663   | correct: False
# Key: 101000000 with probability 0.00012298752024116373   | correct: False
# Key: 000101000 with probability 0.00012298752024116332   | correct: False
# Key: 000000101 with probability 0.000122987520241163   | correct: False
# Key: 111011100 with probability 0.00012106131668071079   | correct: False
# Key: 100011111 with probability 0.00012106131668071023   | correct: False
# Key: 100111011 with probability 0.0001210613166807102   | correct: False
# Key: 111100011 with probability 0.00012106131668070997   | correct: False
# Key: 011100111 with probability 0.00012106131668070922   | correct: False
# Key: 011111100 with probability 0.00012106131668070913   | correct: False
# Key: 010001111 with probability 0.00012100592259919395   | correct: False
# Key: 001010111 with probability 0.00012100592259919353   | correct: False
# Key: 001111010 with probability 0.00012100592259919334   | correct: False
# Key: 010111001 with probability 0.00012100592259919287   | correct: False
# Key: 111001010 with probability 0.00012100592259919281   | correct: False
# Key: 111010001 with probability 0.00012100592259919262   | correct: False
# Key: 111100101 with probability 0.00011291734136175896   | correct: False
# Key: 100111101 with probability 0.00011291734136175882   | correct: False
# Key: 100101111 with probability 0.0001129173413617585   | correct: False
# Key: 101111100 with probability 0.00011291734136175843   | correct: False
# Key: 111101100 with probability 0.00011291734136175725   | correct: False
# Key: 101100111 with probability 0.00011291734136175687   | correct: False
# Key: 111111101 with probability 0.00010450373776116313   | correct: False
# Key: 101111111 with probability 0.00010450373776116295   | correct: False
# Key: 111101111 with probability 0.00010450373776116146   | correct: False
# Key: 011101111 with probability 0.00010156652489821873   | correct: False
# Key: 101111011 with probability 0.00010156652489821849   | correct: False
# Key: 101011111 with probability 0.00010156652489821831   | correct: False
# Key: 111101011 with probability 0.00010156652489821804   | correct: False
# Key: 011111101 with probability 0.00010156652489821776   | correct: False
# Key: 111011101 with probability 0.00010156652489821731   | correct: False
# Key: 111100010 with probability 9.750228113551107e-05   | correct: False
# Key: 111010100 with probability 9.750228113551031e-05   | correct: False
# Key: 100111010 with probability 9.750228113550919e-05   | correct: False
# Key: 100010111 with probability 9.750228113550915e-05   | correct: False
# Key: 010100111 with probability 9.750228113550888e-05   | correct: False
# Key: 010111100 with probability 9.750228113550815e-05   | correct: False
# Key: 100001111 with probability 9.513064897539257e-05   | correct: False
# Key: 001100111 with probability 9.513064897539235e-05   | correct: False
# Key: 001111100 with probability 9.513064897539234e-05   | correct: False
# Key: 111001100 with probability 9.513064897539163e-05   | correct: False
# Key: 100111001 with probability 9.513064897539158e-05   | correct: False
# Key: 111100001 with probability 9.51306489753913e-05   | correct: False
# Key: 101001111 with probability 8.772425768009025e-05   | correct: False
# Key: 001111101 with probability 8.772425768009017e-05   | correct: False
# Key: 111001101 with probability 8.772425768008968e-05   | correct: False
# Key: 001101111 with probability 8.772425768008936e-05   | correct: False
# Key: 111101001 with probability 8.772425768008925e-05   | correct: False
# Key: 101111001 with probability 8.772425768008914e-05   | correct: False
# Key: 101101111 with probability 8.012106551251153e-05   | correct: False
# Key: 101111101 with probability 8.012106551251146e-05   | correct: False
# Key: 111101101 with probability 8.012106551251085e-05   | correct: False
# Key: 110100111 with probability 7.3862559403396e-05   | correct: False
# Key: 100111110 with probability 7.38625594033953e-05   | correct: False
# Key: 111100110 with probability 7.386255940339503e-05   | correct: False
# Key: 111110100 with probability 7.386255940339485e-05   | correct: False
# Key: 110111100 with probability 7.386255940339457e-05   | correct: False
# Key: 100110111 with probability 7.386255940339452e-05   | correct: False
# Key: 110111001 with probability 7.320186855441436e-05   | correct: False
# Key: 111110001 with probability 7.32018685544135e-05   | correct: False
# Key: 001110111 with probability 7.320186855441344e-05   | correct: False
# Key: 001111110 with probability 7.320186855441339e-05   | correct: False
# Key: 110001111 with probability 7.320186855441328e-05   | correct: False
# Key: 111001110 with probability 7.32018685544129e-05   | correct: False
# Key: 110111111 with probability 7.234786360422857e-05   | correct: False
# Key: 111110111 with probability 7.234786360422843e-05   | correct: False
# Key: 111111110 with probability 7.234786360422835e-05   | correct: False
# Key: 011110010 with probability 7.084706399551088e-05   | correct: False
# Key: 011010110 with probability 7.08470639955105e-05   | correct: False
# Key: 110010011 with probability 7.084706399551049e-05   | correct: False
# Key: 010011110 with probability 7.084706399551041e-05   | correct: False
# Key: 010110011 with probability 7.084706399551017e-05   | correct: False
# Key: 110011010 with probability 7.084706399550979e-05   | correct: False
# Key: 110101101 with probability 6.285566489085638e-05   | correct: False
# Key: 101110101 with probability 6.285566489085631e-05   | correct: False
# Key: 101101110 with probability 6.285566489085576e-05   | correct: False
# Key: 110110101 with probability 5.8964768477945646e-05   | correct: False
# Key: 101110110 with probability 5.8964768477945e-05   | correct: False
# Key: 110101110 with probability 5.89647684779449e-05   | correct: False
# Key: 100000111 with probability 5.893605830615913e-05   | correct: False
# Key: 111100000 with probability 5.8936058306158525e-05   | correct: False
# Key: 111000100 with probability 5.893605830615838e-05   | correct: False
# Key: 100111000 with probability 5.893605830615834e-05   | correct: False
# Key: 000111100 with probability 5.8936058306158234e-05   | correct: False
# Key: 000100111 with probability 5.8936058306158004e-05   | correct: False
# Key: 010101111 with probability 5.337504479207965e-05   | correct: False
# Key: 010111101 with probability 5.33750447920795e-05   | correct: False
# Key: 101111010 with probability 5.337504479207946e-05   | correct: False
# Key: 111010101 with probability 5.337504479207917e-05   | correct: False
# Key: 101010111 with probability 5.3375044792079005e-05   | correct: False
# Key: 111101010 with probability 5.337504479207803e-05   | correct: False
# Key: 011011101 with probability 5.110670805963605e-05   | correct: False
# Key: 011101011 with probability 5.11067080596356e-05   | correct: False
# Key: 101011011 with probability 5.11067080596352e-05   | correct: False
# Key: 110011011 with probability 5.0455313660665065e-05   | correct: False
# Key: 011110011 with probability 5.0455313660664754e-05   | correct: False
# Key: 011011110 with probability 5.0455313660664415e-05   | correct: False
# Key: 001101011 with probability 3.3325244937556874e-05   | correct: False
# Key: 011101001 with probability 3.332524493755673e-05   | correct: False
# Key: 001011101 with probability 3.332524493755667e-05   | correct: False
# Key: 011001101 with probability 3.332524493755624e-05   | correct: False
# Key: 101011001 with probability 3.332524493755586e-05   | correct: False
# Key: 101001011 with probability 3.332524493755559e-05   | correct: False
# Key: 111010110 with probability 3.255450339180793e-05   | correct: False
# Key: 010110111 with probability 3.2554503391807703e-05   | correct: False
# Key: 111110010 with probability 3.2554503391807534e-05   | correct: False
# Key: 110111010 with probability 3.25545033918075e-05   | correct: False
# Key: 110010111 with probability 3.255450339180731e-05   | correct: False
# Key: 010111110 with probability 3.255450339180689e-05   | correct: False
# Key: 111111100 with probability 2.534230123067861e-05   | correct: False
# Key: 100111111 with probability 2.5342301230678607e-05   | correct: False
# Key: 111100111 with probability 2.534230123067838e-05   | correct: False
# Key: 001011111 with probability 2.1867521402522475e-05   | correct: False
# Key: 111011001 with probability 2.18675214025224e-05   | correct: False
# Key: 111001011 with probability 2.1867521402522167e-05   | correct: False
# Key: 011111001 with probability 2.1867521402521845e-05   | correct: False
# Key: 011001111 with probability 2.1867521402521838e-05   | correct: False
# Key: 001111011 with probability 2.186752140252173e-05   | correct: False
# Key: 110110111 with probability 1.1506089090717505e-05   | correct: False
# Key: 111110110 with probability 1.1506089090717393e-05   | correct: False
# Key: 110111110 with probability 1.1506089090717355e-05   | correct: False
# Key: 011111111 with probability 1.0201712169979387e-05   | correct: False
# Key: 111011111 with probability 1.0201712169979321e-05   | correct: False
# Key: 111111011 with probability 1.0201712169979245e-05   | correct: False
# Key: 011010111 with probability 9.498683815949646e-06   | correct: False
# Key: 011111010 with probability 9.498683815949592e-06   | correct: False
# Key: 010011111 with probability 9.498683815949579e-06   | correct: False
# Key: 111010011 with probability 9.49868381594925e-06   | correct: False
# Key: 111011010 with probability 9.498683815949242e-06   | correct: False
# Key: 010111011 with probability 9.49868381594918e-06   | correct: False
# Key: 101111110 with probability 7.710969870258609e-06   | correct: False
# Key: 111101110 with probability 7.71096987025852e-06   | correct: False
# Key: 111110101 with probability 7.71096987025851e-06   | correct: False
# Key: 110111101 with probability 7.710969870258438e-06   | correct: False
# Key: 101110111 with probability 7.710969870258372e-06   | correct: False
# Key: 110101111 with probability 7.71096987025816e-06   | correct: False
# Key: 001111111 with probability 1.9556691804658484e-06   | correct: False
# Key: 111111001 with probability 1.955669180465785e-06   | correct: False
# Key: 111001111 with probability 1.9556691804657374e-06   | correct: False
# Key: 111010111 with probability 1.3370483144086197e-06   | correct: False
# Key: 111111010 with probability 1.3370483144086038e-06   | correct: False
# Key: 010111111 with probability 1.3370483144085153e-06   | correct: False

# %%
plt.style.use("seaborn")
plt.bar(range(2 ** (n ** 2)), probs)
plt.show()
